# %% [markdown]
# ## Ejercicio 1: Optimización de un sistema de gestión de bibliotecas
#
# Se le proporciona un código que simula un sistema de gestión de bibliotecas. El sistema tiene la capacidad de añadir libros a la biblioteca, prestar libros a los lectores y recibir libros de vuelta. Además, también puede listar todos los libros disponibles en la biblioteca.
#
# El problema es que el sistema es muy lento y necesita ser optimizado. Su tarea consiste en analizar el código, identificar las áreas de mejora y reescribir partes del código para hacerlo más eficiente. En concreto, se le pide que realice las siguientes mejoras (actualice el código de abajo e implemente los siguientes puntos):
#
# 1. Identifique y mejore las estructuras de datos utilizadas para almacenar los libros en la biblioteca y los libros prestados. *Pista: Utiliza un `set` en lugar de una `list` para almacenar libros en `Library.books` y `Library.borrowed_books` para que sea más eficiente comprobar si un libro está presente.**.
#
# 2. 2. Evitar errores que podrían ocurrir al intentar tomar prestado o devolver un libro que no está presente. *Sugerencia: Utilice el método `set.discard()` en lugar de `list.remove()` en `Library.borrow_book()` y `Library.return_book()` para evitar errores si el libro no está presente.
#
# 3. Mejorar la eficiencia de la selección de un libro al azar para prestar o devolver. *Pista: En lugar de seleccionar un libro al azar de `Library.books` o `Library.borrowed_books` por indexación (lo que implica una conversión a lista que es cara), puedes convertir estos conjuntos a listas sólo una vez antes del ciclo.*
#
# 4. Mejorar la eficiencia de la función que lista todos los libros disponibles en la biblioteca. *Pista: En lugar de imprimir cada libro uno a uno en `Library.list_books()`, puedes construir una cadena completa con todos los títulos de los libros y luego imprimir esa cadena una sola vez.*
#
# 5. Evite las llamadas repetidas a `len()` en el cuerpo de los bucles.
#
# 6. Utilice la comprensión de listas para mejorar la eficiencia de la creación de libros... *Pista: Utilice la comprensión de listas para la creación de libros, que puede ser más rápida que utilizar un bucle for y llamar repetidamente a `Library.add_book()`.*
#
# 7. Optimizar la comprobación de la disponibilidad de los libros prestados antes de intentar devolverlos. *Sugerencia: Evite comprobar `if library.borrowed_books:` antes de intentar devolver un libro. Si utiliza conjuntos y el método `discard()`, no hay necesidad de esta comprobación.*

# %%
import random
import time

class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

class Library:
    def __init__(self, name):
        self.name = name
        self.books = {} 
        self.borrowed_books = {}

    def add_book(self, book):
        if book.title not in self.books: #
            self.books[book.title] = book #
            return True
        return False

    def borrow_book(self, book_title):
        if book_title in self.books: #
            book = self.books.pop(book_title) #
            self.borrowed_books[book.title] = book #
            return True
        return False

    def return_book(self, book_title):
        if book_title in self.borrowed_books: #
            book = self.borrowed_books.pop(book_title) #
            self.books[book.title] = book #
            return True
        return False

    def list_books(self):
        for book_title in self.books: #
            print(self.books[book_title].title) #


library = Library("Codeville")


library.books = {f"Book {i}": Book(f"Book {i}", f"Author {i}", i*10) for i in range(1, 101)}

[library.borrow_book(random.choice(list(library.books.keys()))) for _ in range(50)]



[library.return_book(random.choice(list(library.borrowed_books.keys()))) for _ in range(25) if library.borrowed_books]


start_time = time.time()
library.list_books()
end_time = time.time()
print(f"Listar los libros (usando time) tomó {end_time - start_time} segundos")
# Out:
# Book 1
# Book 3
# Book 4
# Book 7
# Book 10
# Book 15
# Book 16
# Book 19
# Book 20
# Book 21
# Book 22
# Book 24
# Book 25
# Book 26
# Book 28
# Book 29
# Book 31
# Book 33
# Book 34
# Book 35
# Book 39
# Book 40
# Book 44
# Book 48
# Book 49
# Book 50
# Book 55
# Book 56
# Book 57
# Book 59
# Book 60
# Book 61
# Book 62
# Book 65
# Book 66
# Book 70
# Book 72
# Book 73
# Book 76
# Book 80
# Book 81
# Book 83
# Book 91
# Book 92
# Book 94
# Book 95
# Book 96
# Book 97
# Book 98
# Book 99
# Book 41
# Book 36
# Book 17
# Book 68
# Book 52
# Book 85
# Book 37
# Book 9
# Book 84
# Book 58
# Book 13
# Book 46
# Book 43
# Book 79
# Book 23
# Book 64
# Book 11
# Book 86
# Book 71
# Book 38
# Book 2
# Book 78
# Book 32
# Book 45
# Book 100
# Listar los libros (usando time) tomó 0.0009961128234863281 segundos

# %% [markdown]
# ## Ejercicio 2: Optimización del sistema de gestión de tareas
#
# Se le proporciona un código que simula un sistema de gestión de tareas. El sistema tiene la capacidad de añadir tareas, marcar tareas como completadas y listar todas las tareas junto con su estado.
#
# Como en el primer ejercicio, el sistema es bastante lento y necesita ser optimizado. Su tarea consiste en analizar el código, identificar las áreas que podrían mejorarse y reescribir partes del código para hacerlo más eficiente. En concreto, se le pide que realice las siguientes tareas:
#
# 1. Identificar y mejorar las estructuras de datos utilizadas para almacenar las tareas. *Pista: Utiliza un `set` o `dict` en lugar de una `list` para almacenar las tareas en `TaskManager`, para hacer más eficiente la comprobación de la existencia de una tarea.*
#
# 2. 2. Evitar comprobar si una tarea está en la lista de tareas cada vez que se completa una tarea. *Sugerencia: Evite comprobar la existencia de una tarea en `TaskManager.complete_task()`. Si estás seguro de que la tarea proviene de `TaskManager.tasks`, no es necesario comprobar si está en la lista.*
#
# 3. Reestructurar la forma en que se realiza el seguimiento del estado de las tareas. *Pista: En lugar de marcar una tarea como completada modificando su atributo `is_done`, puedes considerar tener dos conjuntos o listas en `TaskManager`: uno para tareas pendientes y otro para tareas completadas.*
#
# 4. Utilice la comprensión de listas para mejorar la eficiencia de la creación de tareas. *Pista: Utilice una comprensión de lista para la creación de tareas, lo que puede ser más rápido que utilizar un bucle for y llamar repetidamente a `TaskManager.add_task()`.*
#
# 5. 5. Mejorar la eficiencia de la función que lista todas las tareas. *Pista: En lugar de imprimir cada tarea una a una en `TaskManager.list_tasks()`, puede construir una cadena completa con todas las tareas y luego imprimir esa cadena una sola vez.*
#
# 6. Introduzca un atributo `id` para identificar de forma única cada tarea. *Sugerencia: Considere el uso de un atributo `id` en la clase `Task` para identificar de forma única cada tarea. Esto puede facilitar la búsqueda y gestión de tareas.*
#
# 7. 7. Evitar llamadas repetidas a la misma función o método en un bucle. *Sugerencia: Evite llamar repetidamente a la misma función o método en un bucle, como `TaskManager.add_task()` o `TaskManager.complete_task()`.
#
# 8. Evite la repetición de código cuando calcule el estado de una tarea. *Pista: Evitar la repetición de código. En `TaskManager.list_tasks()`, el estado de la tarea se calcula de la misma manera para cada tarea. Puedes considerar añadir un método a la clase `Task` que devuelva el estado como una cadena.*
#
# 9. Mejora la legibilidad del código utilizando nombres de variables descriptivos. *Pista: Mejore la legibilidad del código utilizando nombres de variables descriptivos.*
#
# 10. 10. Cambia la forma de iterar sobre las tareas. *Sugerencia: En lugar de iterar sobre un rango de números y luego indexar la lista de tareas, puede iterar directamente sobre las tareas.

# %%
class Task:
    def __init__(self, description, task_id):         
        self.description = description
        self.is_done = False
        self.id = task_id

    def mark_as_done(self):
        self.is_done = True

    def get_status(self):
        return "done" if self.is_done else "not done"


class TaskManager:
    def __init__(self):
        self.tasks = {}
        self.completed_tasks = set()

    def add_task(self, task):
        self.tasks[task.id] = task

    def complete_task(self, task_id):
        task = self.tasks.get(task_id)
        if task:
            task.mark_as_done()
            self.completed_tasks.add(task_id)
            return True
        return False

    def list_tasks(self):
        tasks_list = [f"Task: {task.description}, Status: {task.get_status()}"
                      for task in self.tasks.values()]
        print("\n".join(tasks_list))



manager = TaskManager()


tasks = [Task(f"Task {i}", i) for i in range(1, 1001)]
[manager.add_task(task) for task in tasks]


[manager.complete_task(i) for i in range(1, 501)]


manager.list_tasks()
# Out:
# Task: Task 1, Status: done
# Task: Task 2, Status: done
# Task: Task 3, Status: done
# Task: Task 4, Status: done
# Task: Task 5, Status: done
# Task: Task 6, Status: done
# Task: Task 7, Status: done
# Task: Task 8, Status: done
# Task: Task 9, Status: done
# Task: Task 10, Status: done
# Task: Task 11, Status: done
# Task: Task 12, Status: done
# Task: Task 13, Status: done
# Task: Task 14, Status: done
# Task: Task 15, Status: done
# Task: Task 16, Status: done
# Task: Task 17, Status: done
# Task: Task 18, Status: done
# Task: Task 19, Status: done
# Task: Task 20, Status: done
# Task: Task 21, Status: done
# Task: Task 22, Status: done
# Task: Task 23, Status: done
# Task: Task 24, Status: done
# Task: Task 25, Status: done
# Task: Task 26, Status: done
# Task: Task 27, Status: done
# Task: Task 28, Status: done
# Task: Task 29, Status: done
# Task: Task 30, Status: done
# Task: Task 31, Status: done
# Task: Task 32, Status: done
# Task: Task 33, Status: done
# Task: Task 34, Status: done
# Task: Task 35, Status: done
# Task: Task 36, Status: done
# Task: Task 37, Status: done
# Task: Task 38, Status: done
# Task: Task 39, Status: done
# Task: Task 40, Status: done
# Task: Task 41, Status: done
# Task: Task 42, Status: done
# Task: Task 43, Status: done
# Task: Task 44, Status: done
# Task: Task 45, Status: done
# Task: Task 46, Status: done
# Task: Task 47, Status: done
# Task: Task 48, Status: done
# Task: Task 49, Status: done
# Task: Task 50, Status: done
# Task: Task 51, Status: done
# Task: Task 52, Status: done
# Task: Task 53, Status: done
# Task: Task 54, Status: done
# Task: Task 55, Status: done
# Task: Task 56, Status: done
# Task: Task 57, Status: done
# Task: Task 58, Status: done
# Task: Task 59, Status: done
# Task: Task 60, Status: done
# Task: Task 61, Status: done
# Task: Task 62, Status: done
# Task: Task 63, Status: done
# Task: Task 64, Status: done
# Task: Task 65, Status: done
# Task: Task 66, Status: done
# Task: Task 67, Status: done
# Task: Task 68, Status: done
# Task: Task 69, Status: done
# Task: Task 70, Status: done
# Task: Task 71, Status: done
# Task: Task 72, Status: done
# Task: Task 73, Status: done
# Task: Task 74, Status: done
# Task: Task 75, Status: done
# Task: Task 76, Status: done
# Task: Task 77, Status: done
# Task: Task 78, Status: done
# Task: Task 79, Status: done
# Task: Task 80, Status: done
# Task: Task 81, Status: done
# Task: Task 82, Status: done
# Task: Task 83, Status: done
# Task: Task 84, Status: done
# Task: Task 85, Status: done
# Task: Task 86, Status: done
# Task: Task 87, Status: done
# Task: Task 88, Status: done
# Task: Task 89, Status: done
# Task: Task 90, Status: done
# Task: Task 91, Status: done
# Task: Task 92, Status: done
# Task: Task 93, Status: done
# Task: Task 94, Status: done
# Task: Task 95, Status: done
# Task: Task 96, Status: done
# Task: Task 97, Status: done
# Task: Task 98, Status: done
# Task: Task 99, Status: done
# Task: Task 100, Status: done
# Task: Task 101, Status: done
# Task: Task 102, Status: done
# Task: Task 103, Status: done
# Task: Task 104, Status: done
# Task: Task 105, Status: done
# Task: Task 106, Status: done
# Task: Task 107, Status: done
# Task: Task 108, Status: done
# Task: Task 109, Status: done
# Task: Task 110, Status: done
# Task: Task 111, Status: done
# Task: Task 112, Status: done
# Task: Task 113, Status: done
# Task: Task 114, Status: done
# Task: Task 115, Status: done
# Task: Task 116, Status: done
# Task: Task 117, Status: done
# Task: Task 118, Status: done
# Task: Task 119, Status: done
# Task: Task 120, Status: done
# Task: Task 121, Status: done
# Task: Task 122, Status: done
# Task: Task 123, Status: done
# Task: Task 124, Status: done
# Task: Task 125, Status: done
# Task: Task 126, Status: done
# Task: Task 127, Status: done
# Task: Task 128, Status: done
# Task: Task 129, Status: done
# Task: Task 130, Status: done
# Task: Task 131, Status: done
# Task: Task 132, Status: done
# Task: Task 133, Status: done
# Task: Task 134, Status: done
# Task: Task 135, Status: done
# Task: Task 136, Status: done
# Task: Task 137, Status: done
# Task: Task 138, Status: done
# Task: Task 139, Status: done
# Task: Task 140, Status: done
# Task: Task 141, Status: done
# Task: Task 142, Status: done
# Task: Task 143, Status: done
# Task: Task 144, Status: done
# Task: Task 145, Status: done
# Task: Task 146, Status: done
# Task: Task 147, Status: done
# Task: Task 148, Status: done
# Task: Task 149, Status: done
# Task: Task 150, Status: done
# Task: Task 151, Status: done
# Task: Task 152, Status: done
# Task: Task 153, Status: done
# Task: Task 154, Status: done
# Task: Task 155, Status: done
# Task: Task 156, Status: done
# Task: Task 157, Status: done
# Task: Task 158, Status: done
# Task: Task 159, Status: done
# Task: Task 160, Status: done
# Task: Task 161, Status: done
# Task: Task 162, Status: done
# Task: Task 163, Status: done
# Task: Task 164, Status: done
# Task: Task 165, Status: done
# Task: Task 166, Status: done
# Task: Task 167, Status: done
# Task: Task 168, Status: done
# Task: Task 169, Status: done
# Task: Task 170, Status: done
# Task: Task 171, Status: done
# Task: Task 172, Status: done
# Task: Task 173, Status: done
# Task: Task 174, Status: done
# Task: Task 175, Status: done
# Task: Task 176, Status: done
# Task: Task 177, Status: done
# Task: Task 178, Status: done
# Task: Task 179, Status: done
# Task: Task 180, Status: done
# Task: Task 181, Status: done
# Task: Task 182, Status: done
# Task: Task 183, Status: done
# Task: Task 184, Status: done
# Task: Task 185, Status: done
# Task: Task 186, Status: done
# Task: Task 187, Status: done
# Task: Task 188, Status: done
# Task: Task 189, Status: done
# Task: Task 190, Status: done
# Task: Task 191, Status: done
# Task: Task 192, Status: done
# Task: Task 193, Status: done
# Task: Task 194, Status: done
# Task: Task 195, Status: done
# Task: Task 196, Status: done
# Task: Task 197, Status: done
# Task: Task 198, Status: done
# Task: Task 199, Status: done
# Task: Task 200, Status: done
# Task: Task 201, Status: done
# Task: Task 202, Status: done
# Task: Task 203, Status: done
# Task: Task 204, Status: done
# Task: Task 205, Status: done
# Task: Task 206, Status: done
# Task: Task 207, Status: done
# Task: Task 208, Status: done
# Task: Task 209, Status: done
# Task: Task 210, Status: done
# Task: Task 211, Status: done
# Task: Task 212, Status: done
# Task: Task 213, Status: done
# Task: Task 214, Status: done
# Task: Task 215, Status: done
# Task: Task 216, Status: done
# Task: Task 217, Status: done
# Task: Task 218, Status: done
# Task: Task 219, Status: done
# Task: Task 220, Status: done
# Task: Task 221, Status: done
# Task: Task 222, Status: done
# Task: Task 223, Status: done
# Task: Task 224, Status: done
# Task: Task 225, Status: done
# Task: Task 226, Status: done
# Task: Task 227, Status: done
# Task: Task 228, Status: done
# Task: Task 229, Status: done
# Task: Task 230, Status: done
# Task: Task 231, Status: done
# Task: Task 232, Status: done
# Task: Task 233, Status: done
# Task: Task 234, Status: done
# Task: Task 235, Status: done
# Task: Task 236, Status: done
# Task: Task 237, Status: done
# Task: Task 238, Status: done
# Task: Task 239, Status: done
# Task: Task 240, Status: done
# Task: Task 241, Status: done
# Task: Task 242, Status: done
# Task: Task 243, Status: done
# Task: Task 244, Status: done
# Task: Task 245, Status: done
# Task: Task 246, Status: done
# Task: Task 247, Status: done
# Task: Task 248, Status: done
# Task: Task 249, Status: done
# Task: Task 250, Status: done
# Task: Task 251, Status: done
# Task: Task 252, Status: done
# Task: Task 253, Status: done
# Task: Task 254, Status: done
# Task: Task 255, Status: done
# Task: Task 256, Status: done
# Task: Task 257, Status: done
# Task: Task 258, Status: done
# Task: Task 259, Status: done
# Task: Task 260, Status: done
# Task: Task 261, Status: done
# Task: Task 262, Status: done
# Task: Task 263, Status: done
# Task: Task 264, Status: done
# Task: Task 265, Status: done
# Task: Task 266, Status: done
# Task: Task 267, Status: done
# Task: Task 268, Status: done
# Task: Task 269, Status: done
# Task: Task 270, Status: done
# Task: Task 271, Status: done
# Task: Task 272, Status: done
# Task: Task 273, Status: done
# Task: Task 274, Status: done
# Task: Task 275, Status: done
# Task: Task 276, Status: done
# Task: Task 277, Status: done
# Task: Task 278, Status: done
# Task: Task 279, Status: done
# Task: Task 280, Status: done
# Task: Task 281, Status: done
# Task: Task 282, Status: done
# Task: Task 283, Status: done
# Task: Task 284, Status: done
# Task: Task 285, Status: done
# Task: Task 286, Status: done
# Task: Task 287, Status: done
# Task: Task 288, Status: done
# Task: Task 289, Status: done
# Task: Task 290, Status: done
# Task: Task 291, Status: done
# Task: Task 292, Status: done
# Task: Task 293, Status: done
# Task: Task 294, Status: done
# Task: Task 295, Status: done
# Task: Task 296, Status: done
# Task: Task 297, Status: done
# Task: Task 298, Status: done
# Task: Task 299, Status: done
# Task: Task 300, Status: done
# Task: Task 301, Status: done
# Task: Task 302, Status: done
# Task: Task 303, Status: done
# Task: Task 304, Status: done
# Task: Task 305, Status: done
# Task: Task 306, Status: done
# Task: Task 307, Status: done
# Task: Task 308, Status: done
# Task: Task 309, Status: done
# Task: Task 310, Status: done
# Task: Task 311, Status: done
# Task: Task 312, Status: done
# Task: Task 313, Status: done
# Task: Task 314, Status: done
# Task: Task 315, Status: done
# Task: Task 316, Status: done
# Task: Task 317, Status: done
# Task: Task 318, Status: done
# Task: Task 319, Status: done
# Task: Task 320, Status: done
# Task: Task 321, Status: done
# Task: Task 322, Status: done
# Task: Task 323, Status: done
# Task: Task 324, Status: done
# Task: Task 325, Status: done
# Task: Task 326, Status: done
# Task: Task 327, Status: done
# Task: Task 328, Status: done
# Task: Task 329, Status: done
# Task: Task 330, Status: done
# Task: Task 331, Status: done
# Task: Task 332, Status: done
# Task: Task 333, Status: done
# Task: Task 334, Status: done
# Task: Task 335, Status: done
# Task: Task 336, Status: done
# Task: Task 337, Status: done
# Task: Task 338, Status: done
# Task: Task 339, Status: done
# Task: Task 340, Status: done
# Task: Task 341, Status: done
# Task: Task 342, Status: done
# Task: Task 343, Status: done
# Task: Task 344, Status: done
# Task: Task 345, Status: done
# Task: Task 346, Status: done
# Task: Task 347, Status: done
# Task: Task 348, Status: done
# Task: Task 349, Status: done
# Task: Task 350, Status: done
# Task: Task 351, Status: done
# Task: Task 352, Status: done
# Task: Task 353, Status: done
# Task: Task 354, Status: done
# Task: Task 355, Status: done
# Task: Task 356, Status: done
# Task: Task 357, Status: done
# Task: Task 358, Status: done
# Task: Task 359, Status: done
# Task: Task 360, Status: done
# Task: Task 361, Status: done
# Task: Task 362, Status: done
# Task: Task 363, Status: done
# Task: Task 364, Status: done
# Task: Task 365, Status: done
# Task: Task 366, Status: done
# Task: Task 367, Status: done
# Task: Task 368, Status: done
# Task: Task 369, Status: done
# Task: Task 370, Status: done
# Task: Task 371, Status: done
# Task: Task 372, Status: done
# Task: Task 373, Status: done
# Task: Task 374, Status: done
# Task: Task 375, Status: done
# Task: Task 376, Status: done
# Task: Task 377, Status: done
# Task: Task 378, Status: done
# Task: Task 379, Status: done
# Task: Task 380, Status: done
# Task: Task 381, Status: done
# Task: Task 382, Status: done
# Task: Task 383, Status: done
# Task: Task 384, Status: done
# Task: Task 385, Status: done
# Task: Task 386, Status: done
# Task: Task 387, Status: done
# Task: Task 388, Status: done
# Task: Task 389, Status: done
# Task: Task 390, Status: done
# Task: Task 391, Status: done
# Task: Task 392, Status: done
# Task: Task 393, Status: done
# Task: Task 394, Status: done
# Task: Task 395, Status: done
# Task: Task 396, Status: done
# Task: Task 397, Status: done
# Task: Task 398, Status: done
# Task: Task 399, Status: done
# Task: Task 400, Status: done
# Task: Task 401, Status: done
# Task: Task 402, Status: done
# Task: Task 403, Status: done
# Task: Task 404, Status: done
# Task: Task 405, Status: done
# Task: Task 406, Status: done
# Task: Task 407, Status: done
# Task: Task 408, Status: done
# Task: Task 409, Status: done
# Task: Task 410, Status: done
# Task: Task 411, Status: done
# Task: Task 412, Status: done
# Task: Task 413, Status: done
# Task: Task 414, Status: done
# Task: Task 415, Status: done
# Task: Task 416, Status: done
# Task: Task 417, Status: done
# Task: Task 418, Status: done
# Task: Task 419, Status: done
# Task: Task 420, Status: done
# Task: Task 421, Status: done
# Task: Task 422, Status: done
# Task: Task 423, Status: done
# Task: Task 424, Status: done
# Task: Task 425, Status: done
# Task: Task 426, Status: done
# Task: Task 427, Status: done
# Task: Task 428, Status: done
# Task: Task 429, Status: done
# Task: Task 430, Status: done
# Task: Task 431, Status: done
# Task: Task 432, Status: done
# Task: Task 433, Status: done
# Task: Task 434, Status: done
# Task: Task 435, Status: done
# Task: Task 436, Status: done
# Task: Task 437, Status: done
# Task: Task 438, Status: done
# Task: Task 439, Status: done
# Task: Task 440, Status: done
# Task: Task 441, Status: done
# Task: Task 442, Status: done
# Task: Task 443, Status: done
# Task: Task 444, Status: done
# Task: Task 445, Status: done
# Task: Task 446, Status: done
# Task: Task 447, Status: done
# Task: Task 448, Status: done
# Task: Task 449, Status: done
# Task: Task 450, Status: done
# Task: Task 451, Status: done
# Task: Task 452, Status: done
# Task: Task 453, Status: done
# Task: Task 454, Status: done
# Task: Task 455, Status: done
# Task: Task 456, Status: done
# Task: Task 457, Status: done
# Task: Task 458, Status: done
# Task: Task 459, Status: done
# Task: Task 460, Status: done
# Task: Task 461, Status: done
# Task: Task 462, Status: done
# Task: Task 463, Status: done
# Task: Task 464, Status: done
# Task: Task 465, Status: done
# Task: Task 466, Status: done
# Task: Task 467, Status: done
# Task: Task 468, Status: done
# Task: Task 469, Status: done
# Task: Task 470, Status: done
# Task: Task 471, Status: done
# Task: Task 472, Status: done
# Task: Task 473, Status: done
# Task: Task 474, Status: done
# Task: Task 475, Status: done
# Task: Task 476, Status: done
# Task: Task 477, Status: done
# Task: Task 478, Status: done
# Task: Task 479, Status: done
# Task: Task 480, Status: done
# Task: Task 481, Status: done
# Task: Task 482, Status: done
# Task: Task 483, Status: done
# Task: Task 484, Status: done
# Task: Task 485, Status: done
# Task: Task 486, Status: done
# Task: Task 487, Status: done
# Task: Task 488, Status: done
# Task: Task 489, Status: done
# Task: Task 490, Status: done
# Task: Task 491, Status: done
# Task: Task 492, Status: done
# Task: Task 493, Status: done
# Task: Task 494, Status: done
# Task: Task 495, Status: done
# Task: Task 496, Status: done
# Task: Task 497, Status: done
# Task: Task 498, Status: done
# Task: Task 499, Status: done
# Task: Task 500, Status: done
# Task: Task 501, Status: not done
# Task: Task 502, Status: not done
# Task: Task 503, Status: not done
# Task: Task 504, Status: not done
# Task: Task 505, Status: not done
# Task: Task 506, Status: not done
# Task: Task 507, Status: not done
# Task: Task 508, Status: not done
# Task: Task 509, Status: not done
# Task: Task 510, Status: not done
# Task: Task 511, Status: not done
# Task: Task 512, Status: not done
# Task: Task 513, Status: not done
# Task: Task 514, Status: not done
# Task: Task 515, Status: not done
# Task: Task 516, Status: not done
# Task: Task 517, Status: not done
# Task: Task 518, Status: not done
# Task: Task 519, Status: not done
# Task: Task 520, Status: not done
# Task: Task 521, Status: not done
# Task: Task 522, Status: not done
# Task: Task 523, Status: not done
# Task: Task 524, Status: not done
# Task: Task 525, Status: not done
# Task: Task 526, Status: not done
# Task: Task 527, Status: not done
# Task: Task 528, Status: not done
# Task: Task 529, Status: not done
# Task: Task 530, Status: not done
# Task: Task 531, Status: not done
# Task: Task 532, Status: not done
# Task: Task 533, Status: not done
# Task: Task 534, Status: not done
# Task: Task 535, Status: not done
# Task: Task 536, Status: not done
# Task: Task 537, Status: not done
# Task: Task 538, Status: not done
# Task: Task 539, Status: not done
# Task: Task 540, Status: not done
# Task: Task 541, Status: not done
# Task: Task 542, Status: not done
# Task: Task 543, Status: not done
# Task: Task 544, Status: not done
# Task: Task 545, Status: not done
# Task: Task 546, Status: not done
# Task: Task 547, Status: not done
# Task: Task 548, Status: not done
# Task: Task 549, Status: not done
# Task: Task 550, Status: not done
# Task: Task 551, Status: not done
# Task: Task 552, Status: not done
# Task: Task 553, Status: not done
# Task: Task 554, Status: not done
# Task: Task 555, Status: not done
# Task: Task 556, Status: not done
# Task: Task 557, Status: not done
# Task: Task 558, Status: not done
# Task: Task 559, Status: not done
# Task: Task 560, Status: not done
# Task: Task 561, Status: not done
# Task: Task 562, Status: not done
# Task: Task 563, Status: not done
# Task: Task 564, Status: not done
# Task: Task 565, Status: not done
# Task: Task 566, Status: not done
# Task: Task 567, Status: not done
# Task: Task 568, Status: not done
# Task: Task 569, Status: not done
# Task: Task 570, Status: not done
# Task: Task 571, Status: not done
# Task: Task 572, Status: not done
# Task: Task 573, Status: not done
# Task: Task 574, Status: not done
# Task: Task 575, Status: not done
# Task: Task 576, Status: not done
# Task: Task 577, Status: not done
# Task: Task 578, Status: not done
# Task: Task 579, Status: not done
# Task: Task 580, Status: not done
# Task: Task 581, Status: not done
# Task: Task 582, Status: not done
# Task: Task 583, Status: not done
# Task: Task 584, Status: not done
# Task: Task 585, Status: not done
# Task: Task 586, Status: not done
# Task: Task 587, Status: not done
# Task: Task 588, Status: not done
# Task: Task 589, Status: not done
# Task: Task 590, Status: not done
# Task: Task 591, Status: not done
# Task: Task 592, Status: not done
# Task: Task 593, Status: not done
# Task: Task 594, Status: not done
# Task: Task 595, Status: not done
# Task: Task 596, Status: not done
# Task: Task 597, Status: not done
# Task: Task 598, Status: not done
# Task: Task 599, Status: not done
# Task: Task 600, Status: not done
# Task: Task 601, Status: not done
# Task: Task 602, Status: not done
# Task: Task 603, Status: not done
# Task: Task 604, Status: not done
# Task: Task 605, Status: not done
# Task: Task 606, Status: not done
# Task: Task 607, Status: not done
# Task: Task 608, Status: not done
# Task: Task 609, Status: not done
# Task: Task 610, Status: not done
# Task: Task 611, Status: not done
# Task: Task 612, Status: not done
# Task: Task 613, Status: not done
# Task: Task 614, Status: not done
# Task: Task 615, Status: not done
# Task: Task 616, Status: not done
# Task: Task 617, Status: not done
# Task: Task 618, Status: not done
# Task: Task 619, Status: not done
# Task: Task 620, Status: not done
# Task: Task 621, Status: not done
# Task: Task 622, Status: not done
# Task: Task 623, Status: not done
# Task: Task 624, Status: not done
# Task: Task 625, Status: not done
# Task: Task 626, Status: not done
# Task: Task 627, Status: not done
# Task: Task 628, Status: not done
# Task: Task 629, Status: not done
# Task: Task 630, Status: not done
# Task: Task 631, Status: not done
# Task: Task 632, Status: not done
# Task: Task 633, Status: not done
# Task: Task 634, Status: not done
# Task: Task 635, Status: not done
# Task: Task 636, Status: not done
# Task: Task 637, Status: not done
# Task: Task 638, Status: not done
# Task: Task 639, Status: not done
# Task: Task 640, Status: not done
# Task: Task 641, Status: not done
# Task: Task 642, Status: not done
# Task: Task 643, Status: not done
# Task: Task 644, Status: not done
# Task: Task 645, Status: not done
# Task: Task 646, Status: not done
# Task: Task 647, Status: not done
# Task: Task 648, Status: not done
# Task: Task 649, Status: not done
# Task: Task 650, Status: not done
# Task: Task 651, Status: not done
# Task: Task 652, Status: not done
# Task: Task 653, Status: not done
# Task: Task 654, Status: not done
# Task: Task 655, Status: not done
# Task: Task 656, Status: not done
# Task: Task 657, Status: not done
# Task: Task 658, Status: not done
# Task: Task 659, Status: not done
# Task: Task 660, Status: not done
# Task: Task 661, Status: not done
# Task: Task 662, Status: not done
# Task: Task 663, Status: not done
# Task: Task 664, Status: not done
# Task: Task 665, Status: not done
# Task: Task 666, Status: not done
# Task: Task 667, Status: not done
# Task: Task 668, Status: not done
# Task: Task 669, Status: not done
# Task: Task 670, Status: not done
# Task: Task 671, Status: not done
# Task: Task 672, Status: not done
# Task: Task 673, Status: not done
# Task: Task 674, Status: not done
# Task: Task 675, Status: not done
# Task: Task 676, Status: not done
# Task: Task 677, Status: not done
# Task: Task 678, Status: not done
# Task: Task 679, Status: not done
# Task: Task 680, Status: not done
# Task: Task 681, Status: not done
# Task: Task 682, Status: not done
# Task: Task 683, Status: not done
# Task: Task 684, Status: not done
# Task: Task 685, Status: not done
# Task: Task 686, Status: not done
# Task: Task 687, Status: not done
# Task: Task 688, Status: not done
# Task: Task 689, Status: not done
# Task: Task 690, Status: not done
# Task: Task 691, Status: not done
# Task: Task 692, Status: not done
# Task: Task 693, Status: not done
# Task: Task 694, Status: not done
# Task: Task 695, Status: not done
# Task: Task 696, Status: not done
# Task: Task 697, Status: not done
# Task: Task 698, Status: not done
# Task: Task 699, Status: not done
# Task: Task 700, Status: not done
# Task: Task 701, Status: not done
# Task: Task 702, Status: not done
# Task: Task 703, Status: not done
# Task: Task 704, Status: not done
# Task: Task 705, Status: not done
# Task: Task 706, Status: not done
# Task: Task 707, Status: not done
# Task: Task 708, Status: not done
# Task: Task 709, Status: not done
# Task: Task 710, Status: not done
# Task: Task 711, Status: not done
# Task: Task 712, Status: not done
# Task: Task 713, Status: not done
# Task: Task 714, Status: not done
# Task: Task 715, Status: not done
# Task: Task 716, Status: not done
# Task: Task 717, Status: not done
# Task: Task 718, Status: not done
# Task: Task 719, Status: not done
# Task: Task 720, Status: not done
# Task: Task 721, Status: not done
# Task: Task 722, Status: not done
# Task: Task 723, Status: not done
# Task: Task 724, Status: not done
# Task: Task 725, Status: not done
# Task: Task 726, Status: not done
# Task: Task 727, Status: not done
# Task: Task 728, Status: not done
# Task: Task 729, Status: not done
# Task: Task 730, Status: not done
# Task: Task 731, Status: not done
# Task: Task 732, Status: not done
# Task: Task 733, Status: not done
# Task: Task 734, Status: not done
# Task: Task 735, Status: not done
# Task: Task 736, Status: not done
# Task: Task 737, Status: not done
# Task: Task 738, Status: not done
# Task: Task 739, Status: not done
# Task: Task 740, Status: not done
# Task: Task 741, Status: not done
# Task: Task 742, Status: not done
# Task: Task 743, Status: not done
# Task: Task 744, Status: not done
# Task: Task 745, Status: not done
# Task: Task 746, Status: not done
# Task: Task 747, Status: not done
# Task: Task 748, Status: not done
# Task: Task 749, Status: not done
# Task: Task 750, Status: not done
# Task: Task 751, Status: not done
# Task: Task 752, Status: not done
# Task: Task 753, Status: not done
# Task: Task 754, Status: not done
# Task: Task 755, Status: not done
# Task: Task 756, Status: not done
# Task: Task 757, Status: not done
# Task: Task 758, Status: not done
# Task: Task 759, Status: not done
# Task: Task 760, Status: not done
# Task: Task 761, Status: not done
# Task: Task 762, Status: not done
# Task: Task 763, Status: not done
# Task: Task 764, Status: not done
# Task: Task 765, Status: not done
# Task: Task 766, Status: not done
# Task: Task 767, Status: not done
# Task: Task 768, Status: not done
# Task: Task 769, Status: not done
# Task: Task 770, Status: not done
# Task: Task 771, Status: not done
# Task: Task 772, Status: not done
# Task: Task 773, Status: not done
# Task: Task 774, Status: not done
# Task: Task 775, Status: not done
# Task: Task 776, Status: not done
# Task: Task 777, Status: not done
# Task: Task 778, Status: not done
# Task: Task 779, Status: not done
# Task: Task 780, Status: not done
# Task: Task 781, Status: not done
# Task: Task 782, Status: not done
# Task: Task 783, Status: not done
# Task: Task 784, Status: not done
# Task: Task 785, Status: not done
# Task: Task 786, Status: not done
# Task: Task 787, Status: not done
# Task: Task 788, Status: not done
# Task: Task 789, Status: not done
# Task: Task 790, Status: not done
# Task: Task 791, Status: not done
# Task: Task 792, Status: not done
# Task: Task 793, Status: not done
# Task: Task 794, Status: not done
# Task: Task 795, Status: not done
# Task: Task 796, Status: not done
# Task: Task 797, Status: not done
# Task: Task 798, Status: not done
# Task: Task 799, Status: not done
# Task: Task 800, Status: not done
# Task: Task 801, Status: not done
# Task: Task 802, Status: not done
# Task: Task 803, Status: not done
# Task: Task 804, Status: not done
# Task: Task 805, Status: not done
# Task: Task 806, Status: not done
# Task: Task 807, Status: not done
# Task: Task 808, Status: not done
# Task: Task 809, Status: not done
# Task: Task 810, Status: not done
# Task: Task 811, Status: not done
# Task: Task 812, Status: not done
# Task: Task 813, Status: not done
# Task: Task 814, Status: not done
# Task: Task 815, Status: not done
# Task: Task 816, Status: not done
# Task: Task 817, Status: not done
# Task: Task 818, Status: not done
# Task: Task 819, Status: not done
# Task: Task 820, Status: not done
# Task: Task 821, Status: not done
# Task: Task 822, Status: not done
# Task: Task 823, Status: not done
# Task: Task 824, Status: not done
# Task: Task 825, Status: not done
# Task: Task 826, Status: not done
# Task: Task 827, Status: not done
# Task: Task 828, Status: not done
# Task: Task 829, Status: not done
# Task: Task 830, Status: not done
# Task: Task 831, Status: not done
# Task: Task 832, Status: not done
# Task: Task 833, Status: not done
# Task: Task 834, Status: not done
# Task: Task 835, Status: not done
# Task: Task 836, Status: not done
# Task: Task 837, Status: not done
# Task: Task 838, Status: not done
# Task: Task 839, Status: not done
# Task: Task 840, Status: not done
# Task: Task 841, Status: not done
# Task: Task 842, Status: not done
# Task: Task 843, Status: not done
# Task: Task 844, Status: not done
# Task: Task 845, Status: not done
# Task: Task 846, Status: not done
# Task: Task 847, Status: not done
# Task: Task 848, Status: not done
# Task: Task 849, Status: not done
# Task: Task 850, Status: not done
# Task: Task 851, Status: not done
# Task: Task 852, Status: not done
# Task: Task 853, Status: not done
# Task: Task 854, Status: not done
# Task: Task 855, Status: not done
# Task: Task 856, Status: not done
# Task: Task 857, Status: not done
# Task: Task 858, Status: not done
# Task: Task 859, Status: not done
# Task: Task 860, Status: not done
# Task: Task 861, Status: not done
# Task: Task 862, Status: not done
# Task: Task 863, Status: not done
# Task: Task 864, Status: not done
# Task: Task 865, Status: not done
# Task: Task 866, Status: not done
# Task: Task 867, Status: not done
# Task: Task 868, Status: not done
# Task: Task 869, Status: not done
# Task: Task 870, Status: not done
# Task: Task 871, Status: not done
# Task: Task 872, Status: not done
# Task: Task 873, Status: not done
# Task: Task 874, Status: not done
# Task: Task 875, Status: not done
# Task: Task 876, Status: not done
# Task: Task 877, Status: not done
# Task: Task 878, Status: not done
# Task: Task 879, Status: not done
# Task: Task 880, Status: not done
# Task: Task 881, Status: not done
# Task: Task 882, Status: not done
# Task: Task 883, Status: not done
# Task: Task 884, Status: not done
# Task: Task 885, Status: not done
# Task: Task 886, Status: not done
# Task: Task 887, Status: not done
# Task: Task 888, Status: not done
# Task: Task 889, Status: not done
# Task: Task 890, Status: not done
# Task: Task 891, Status: not done
# Task: Task 892, Status: not done
# Task: Task 893, Status: not done
# Task: Task 894, Status: not done
# Task: Task 895, Status: not done
# Task: Task 896, Status: not done
# Task: Task 897, Status: not done
# Task: Task 898, Status: not done
# Task: Task 899, Status: not done
# Task: Task 900, Status: not done
# Task: Task 901, Status: not done
# Task: Task 902, Status: not done
# Task: Task 903, Status: not done
# Task: Task 904, Status: not done
# Task: Task 905, Status: not done
# Task: Task 906, Status: not done
# Task: Task 907, Status: not done
# Task: Task 908, Status: not done
# Task: Task 909, Status: not done
# Task: Task 910, Status: not done
# Task: Task 911, Status: not done
# Task: Task 912, Status: not done
# Task: Task 913, Status: not done
# Task: Task 914, Status: not done
# Task: Task 915, Status: not done
# Task: Task 916, Status: not done
# Task: Task 917, Status: not done
# Task: Task 918, Status: not done
# Task: Task 919, Status: not done
# Task: Task 920, Status: not done
# Task: Task 921, Status: not done
# Task: Task 922, Status: not done
# Task: Task 923, Status: not done
# Task: Task 924, Status: not done
# Task: Task 925, Status: not done
# Task: Task 926, Status: not done
# Task: Task 927, Status: not done
# Task: Task 928, Status: not done
# Task: Task 929, Status: not done
# Task: Task 930, Status: not done
# Task: Task 931, Status: not done
# Task: Task 932, Status: not done
# Task: Task 933, Status: not done
# Task: Task 934, Status: not done
# Task: Task 935, Status: not done
# Task: Task 936, Status: not done
# Task: Task 937, Status: not done
# Task: Task 938, Status: not done
# Task: Task 939, Status: not done
# Task: Task 940, Status: not done
# Task: Task 941, Status: not done
# Task: Task 942, Status: not done
# Task: Task 943, Status: not done
# Task: Task 944, Status: not done
# Task: Task 945, Status: not done
# Task: Task 946, Status: not done
# Task: Task 947, Status: not done
# Task: Task 948, Status: not done
# Task: Task 949, Status: not done
# Task: Task 950, Status: not done
# Task: Task 951, Status: not done
# Task: Task 952, Status: not done
# Task: Task 953, Status: not done
# Task: Task 954, Status: not done
# Task: Task 955, Status: not done
# Task: Task 956, Status: not done
# Task: Task 957, Status: not done
# Task: Task 958, Status: not done
# Task: Task 959, Status: not done
# Task: Task 960, Status: not done
# Task: Task 961, Status: not done
# Task: Task 962, Status: not done
# Task: Task 963, Status: not done
# Task: Task 964, Status: not done
# Task: Task 965, Status: not done
# Task: Task 966, Status: not done
# Task: Task 967, Status: not done
# Task: Task 968, Status: not done
# Task: Task 969, Status: not done
# Task: Task 970, Status: not done
# Task: Task 971, Status: not done
# Task: Task 972, Status: not done
# Task: Task 973, Status: not done
# Task: Task 974, Status: not done
# Task: Task 975, Status: not done
# Task: Task 976, Status: not done
# Task: Task 977, Status: not done
# Task: Task 978, Status: not done
# Task: Task 979, Status: not done
# Task: Task 980, Status: not done
# Task: Task 981, Status: not done
# Task: Task 982, Status: not done
# Task: Task 983, Status: not done
# Task: Task 984, Status: not done
# Task: Task 985, Status: not done
# Task: Task 986, Status: not done
# Task: Task 987, Status: not done
# Task: Task 988, Status: not done
# Task: Task 989, Status: not done
# Task: Task 990, Status: not done
# Task: Task 991, Status: not done
# Task: Task 992, Status: not done
# Task: Task 993, Status: not done
# Task: Task 994, Status: not done
# Task: Task 995, Status: not done
# Task: Task 996, Status: not done
# Task: Task 997, Status: not done
# Task: Task 998, Status: not done
# Task: Task 999, Status: not done
# Task: Task 1000, Status: not done

# %% [markdown]
# Se utiliza un diccionario self.tasks para almacenar las tareas en TaskManager, donde la clave es el task_id único de cada tarea. Esto permite una búsqueda eficiente de tareas y evita la necesidad de comprobar si una tarea existe en una lista.
#
# Se utiliza un conjunto self.completed_tasks para realizar un seguimiento de las tareas completadas. Esto permite una comprobación más rápida de si una tarea está completada o no.
#
# Se ha añadido un atributo id a la clase Task para identificar de forma única cada tarea. Esto facilita la búsqueda y gestión de tareas.
#
# Se utiliza la comprensión de listas en list_tasks() para generar la lista de tareas y luego se imprime utilizando "\n".join() para evitar múltiples llamadas a print().
#
# Se ha añadido un método get_status() a la clase Task para calcular el estado de una tarea como una cadena. Esto evita la repetición de código en list_tasks().
#
# Se han utilizado nombres de variables descriptivos para mejorar la legibilidad del código.
#
# En el bucle for para completar las tareas, se itera directamente sobre los números de tarea en lugar de indexar la lista de tareas
